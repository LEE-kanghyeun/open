# %% [markdown]
# # 과적합 방지

# %% [markdown]
# 오버피팅이란 신경망이 훈련 데이터에만 지나치게 적응되어 그 외의 데이터에는 제대로 대응하지 못하는 상태를 말한다. 이는 주로 다음의 두 경우에 일어난다.
#
# 1. 매개변수가 많고 표현력이 높은 모델
# 2. 훈련 데이터가 적은 경우
#
# MNIST 데이터셋을 활용하면서 고의로 오버피팅을 유발해본다. 60,000개 데이터 중 300개반 사용하고, 네트워크를 7층으로 구성해 복잡성을 높인다.
#
#
# <과적합 방지를 위한 대책>
#
# 1. Layer 또는 노드의 수를 줄인다 (모델의 복잡성을 감소)
#
# 2. 가중치 감쇠 또는 가중치 규제 (모델의 복잡성을 감소)
#
# 3. 드랍 아웃 (데이터 의존성을 감소 ?)
#
# 4. 데이터 양을 늘리거나, 트랜스포메이션 등으로 재활용

# %%
### 오버피팅 발생 조건 재현

# coding: utf-8
import os
import sys
# sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname(__file__))))  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비울 설정 ========================
use_dropout = False  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.3288754482607463
# === epoch:1, train acc:0.15666666666666668, test acc:0.1488 ===
# train loss:2.340677750578172
# train loss:2.2717699935599844
# train loss:2.233111895822542
# === epoch:2, train acc:0.17666666666666667, test acc:0.1642 ===
# train loss:2.314681012318549
# train loss:2.3535973910614816
# train loss:2.2424215215870076
# === epoch:3, train acc:0.22333333333333333, test acc:0.1841 ===
# train loss:2.2475972141390583
# train loss:2.230177753434286
# train loss:2.2112231956014923
# === epoch:4, train acc:0.25, test acc:0.2004 ===
# train loss:2.2591356757687375
# train loss:2.158531420681417
# train loss:2.1925645153598854
# === epoch:5, train acc:0.26666666666666666, test acc:0.2078 ===
# train loss:2.233564401770641
# train loss:2.2073862887393556
# train loss:2.145027368158533
# === epoch:6, train acc:0.2733333333333333, test acc:0.2189 ===
# train loss:2.063229113503473
# train loss:2.1825132569309758
# train loss:2.180070729078307
# ...

# %% [markdown]
# 훈련 데이터를 사용하여 측정한 정확도는 100 에폭을 지나는 무렵부터 거의 100%다.
#
# 그러나 시험 데이터에 대해선 큰 차이를 보인다.
#
# 훈련 데이터에만 적응(fitting)하여 시험 데이터에는 제대로 대응하지 못한 것이다

# %% [markdown]
# 과적합 방지 스킬 : 1) 가중치 감소(Weight Decay)
#
# 가중치 감소란 가중치 매개변수의 값이 작아지도록 학습하는 방법이다. 가중치 값을 작게 하여 오버피팅이 일어나지 않게 하는 것이다. 그렇다고 가중치를 작게 만들기 위해 초기값을 0으로 하게 된다면, 오차역전파법에서 모든 가중치의 값이 똑같이 갱신되기 때문에, 제대로 학습이 이루어지지 않게 된다. 따라서 가중치의 초기값은 무작위로 설정해주는 것이 좋다.
#
# 신경망 학습의 목적은 손실 함수의 값을 줄이는 것이다. 이때 가중치의 제곱 놈(norm)을 손실 함수에 더해 가중치가 커지는 것을 억제하는 것이다. 가중치를 W라 할 때, L2 놈에 따른 가중치 감소는 1/2*λ*W^2가 되고, 이것을 손실함수에 더한다. 여기서 λ는 정규화의 세기를 조절하는 하이퍼파라미터이다. 어쨌든 각각의 손실함수에 1/2λW^2를 더해 가중치가 커지는 것을 억제한다.
#
# 가중치 감소 적용된 Loss function = f(x) + 1/2*λ*W^2
# ![image.png](attachment:image.png)

# %% [markdown]
# - 가중치와 학습

# %% [markdown]
# ### Regularization (가중치 감쇠)
#
# ### L1 Regularization
# ![image.png](attachment:image.png)

# %% [markdown]
# ### L2 Regularization
# ![image.png](attachment:image.png)
#
# ### 주로 L2를 활용

# %% [markdown]
# 다만, L1을 활용하는 경우도 있다. 바로 maxtrix completion과 같이 값이 sparse할때이다.
#
# x⃗ =(1,ε)∈R2, where ε>0  이러한 벡터 x가 있다고 할때
# l1과 l2는 각각 아래와 같은 식이 될 것이다.
#
# ||x⃗ ||_1 =1+ε,  ||x⃗ ||_2 = 1+ε^2
#
# 또한, 벡터 x에 변화가 있다고 하면, 아래 그림처럼 L2값은 너무 작아진다 (L1은 그대로임)
# 이렇게 L2값이 너무 작아지면, 0에 근사하게되어, penalty를 줄수가 없게되므로 이럴때는 L1을 쓴다.
#
# ![20220223_230456.png](attachment:20220223_230456.png)
#
# https://stats.stackexchange.com/questions/45643/why-l1-norm-for-sparse-models
#
# https://wikidocs.net/19034
#
# https://light-tree.tistory.com/125

# %% [markdown]
# 1) 가중치를 작게하는 이유 : 큰 가중치 값이 많다는 것은 그만큼 변수 간 연결강도가 크다는 것이고, 그만큼 모델의 복잡도가 올라가게 된다는 것이다. 즉, 과대적합 가능성이 증가한다. 이때문에 가중치를 작게(가중치 감쇠, Weight Decay)를 한다.
#
# ![download.jfif](attachment:download.jfif)
# https://hyjykelly.tistory.com/50

# %% [markdown]
# 2) 가중치의 값이 균일해서는 안되는 이유 : 오차역전파법에서 모든 가중치의 값이 똑같이 갱신되기 때문이다. 이렇게 되면 가중치를 여러개 갖는 의미가 없다. 따라서 무작위의 값으로 설정되야 한다.

# %%
### 가중치 감쇠 적용

# coding: utf-8
import os
import sys

# sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname(__file__))))  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay（가중치 감쇠） 설정 =======================
#weight_decay_lambda = 0 # weight decay를 사용하지 않을 경우
weight_decay_lambda = 0.1
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01) # 학습률이 0.01인 SGD로 매개변수 갱신

max_epochs = 401          ## epoch 수를 늘림 (301 -> 401)
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break


# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-16e9b1580d7f> in <module>
#       8 import numpy as np
#       9 import matplotlib.pyplot as plt
# ---> 10 from dataset.mnist import load_mnist
#      11 from common.multi_layer_net import MultiLayerNet
#      12 from common.optimizer import SGD
#
# ModuleNotFoundError: No module named 'dataset'

# %% [markdown]
# MultiLayerNet에 포함된 loss 함수 코드 (가중치 감쇠 표현됨)
#
#     def loss(self, x, t):
#         """손실 함수를 구한다.
#
#         Parameters
#         ----------
#         x : 입력 데이터
#         t : 정답 레이블
#
#         Returns
#         -------
#         손실 함수의 값
#         """
#         y = self.predict(x)
#
#         weight_decay = 0
#         for idx in range(1, self.hidden_layer_num + 2):
#             W = self.params['W' + str(idx)]
#             weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W ** 2)
#
#         return self.last_layer.forward(y, t) + weight_decay

# %% [markdown]
# 성능도 줄고, train과 test의 성능 차이 자체도 별로 줄지 않았다.
# 책대로라면, 훈련 데이터에 대한 정확도와 시험 데이터에 대한 정확도에는 여전히 차이가 있지만,
# 가중치 감소를 이용하지 않은 정확도 추이와 비교하면 그 차이가 줄었어야 했다....
# 아래는 책에서 보여준 그래프이다.
# ![image.png](attachment:image.png)

# %% [markdown]
# 과적합 방지 스킬 :   2) 드롭 아웃
# ![image.png](attachment:image.png)
#
# 위에서는 오버피팅을 억제하는 방식으로 손실 함수에 가중치의 L2 노름을 더한 가중치 감소 방법을 말했다.
#
# 가중치 감소는 간단하게 구현할 수 있고 어느 정도 지나친 학습을 억제할 수 있다.
#
# 그러나 신경망 모델이 복잡해지면 드롭아웃(Dropout) 기법을 이용한다.
#
#
#
# 드롭아웃은 뉴런을 임의로 삭제하면서 학습하는 방법이다.
#
# 훈련 때 은닉층의 뉴런을 무작위로 골라 삭제한다.
#
# 삭제된 뉴런은 위 그림과 같이 신호를 전달하지 않는다.
#
# 훈련 때는 데이터를 흘릴 때마다 삭제할 뉴런을 무작위로 선택하고, 시험 때는 모든 뉴런에 신호를 전달한다.
#
# ### 단, 시험 때는 각 뉴런의 출력에 훈련 때 삭제 안 한 비율을 곱하여 출력한다. (테스트 출력값이 5이고, dropout_ratio = 0.2라면 출력값을 5 * 0.8 = 4로 보정)
# ### 그러나, 실제로는 이러한 보정을 하지않고 그냥 출력하는 경우가 많다

# %%
### 드랍아웃 사용

# coding: utf-8
import os
import sys
# sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname(__file__))))  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 오버피팅을 재현하기 위해 학습 데이터 수를 줄임
x_train = x_train[:300]
t_train = t_train[:300]

# 드롭아웃 사용 유무와 비울 설정 ========================
use_dropout = True  # 드롭아웃을 쓰지 않을 때는 False
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# 그래프 그리기==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.3090418973716202
# === epoch:1, train acc:0.13666666666666666, test acc:0.1303 ===
# train loss:2.306744841692369
# train loss:2.3050899943857943
# train loss:2.3138621560542076
# === epoch:2, train acc:0.14, test acc:0.1367 ===
# train loss:2.3039953041758783
# train loss:2.314728136412217
# train loss:2.3314354999962643
# === epoch:3, train acc:0.15333333333333332, test acc:0.1395 ===
# train loss:2.303727841193853
# train loss:2.309992006070631
# train loss:2.309776655741719
# === epoch:4, train acc:0.16, test acc:0.1448 ===
# train loss:2.3138178371311375
# train loss:2.3030784399626807
# train loss:2.2898095609390907
# === epoch:5, train acc:0.18333333333333332, test acc:0.1533 ===
# train loss:2.2933443119578087
# train loss:2.2964051125819704
# train loss:2.3141814374744127
# === epoch:6, train acc:0.18666666666666668, test acc:0.1572 ===
# train loss:2.298420660073213
# train loss:2.294614881035596
# train loss:2.3130283393060718
# ...

# %% [markdown]
# # 하이퍼 파라미터 값 찾기

# %% [markdown]
# 1) 검증 데이터
#
# 지금까지는 데이터셋을 Train/Test 두 가지로 분리해 이용했다.
#
# 실제로는 Train/Validation/Test 이렇게 활용

# %% [markdown]
# 2) 하이퍼파라미터를 최적화할 때의 핵심은 하이퍼파라미터의 최적 값이 존재하는 범위를 조금씩 줄여간다는 것이다. 우선 대략적인 범위를 설정하고, 그 범위 내에서 무작위로 하이퍼파라미터를 샘플링한 후 그 값으로 정확도를 평가한다. 정확도를 살펴보면서 최적값의 범위를 좁혀나가는 것이다.
#
# 1단계 : parameter = {1, 100, 200, 300}
# (결과는 100이 우수)
#
# 2단계 : parameter = {100, 120, 140, 160, 180}
# (결과는 140이 우수)
#
# 3단계 : parameter = {125, 130, 135, 140, 145}
# (결과는 140이 우수)
#
# 이상적인 예시이기는 하지만, 컨셉은 그러하다
#
# ##########################################
#
# <딥러닝에서는 이렇게 적용한다>
#
# 하이퍼파라미터는 1e-3 ~ 1e+3 (0.001 ~ 1000)의 범위 내에서 10의 거듭제곱 단위로 범위를 지정하는 것이 일반적이다. 이를 log scale이라고 한다 (그룹1: 0.001 ~ 0.1,  그룹2: 0.1 ~ 10, 그룹3: 10 ~ 1000)
#
# - 0단계: 하이퍼파라미터 값의 범위를 설정한다. (그룹1: 0.001 ~ 0.1,  그룹2: 0.1 ~ 10, 그룹3: 10 ~ 1000)
# - 1단계: 설정된 범위에서 하이퍼파라미터의 값을 무작위로 추출한다.
# - 2단계: 1단계에서 샘플링한 하이퍼파라미터 값을 사용하여 학습하고, 검증 데이터로 정확도를 평가한다.
# 딥러닝 학습은 오랜 시간이 걸리기 때문에 하이퍼파라미터 최적화에서는 학습을 위한 에폭을 작게 하여, 1회 평가에 걸리는 시간을 단축하는 것이 효과적이다.
# - 3단계: 1단계와 2단계를 반복하며 그 정확도의 결과를 보고 하이퍼파라미터의 범위를 좁혀나간다

# %% [markdown]
# # 하이처 파라미터 최적화 구현

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.util import shuffle_dataset
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 결과를 빠르게 얻기 위해 훈련 데이터를 줄임
x_train = x_train[:500]
t_train = t_train[:500]

# 20%를 검증 데이터로 분할
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]


def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                            output_size=10, weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                      epochs=epocs, mini_batch_size=100,
                      optimizer='sgd', optimizer_param={'lr': lr}, verbose=False)
    ### 파라미터는 학습률 (lr)과 가중치 감쇠 계수 (weight_decay_lambda)로 구성됨 ###
    trainer.train()

    return trainer.test_acc_list, trainer.train_acc_list


# 하이퍼파라미터 무작위 탐색======================================
optimization_trial = 100
results_val = {}
results_train = {}
for _ in range(optimization_trial):
    # 탐색한 하이퍼파라미터의 범위 지정===============
    weight_decay = 10 ** np.random.uniform(-8, -4)  ## 균등(균일) 분포로 무작위 추출함
    lr = 10 ** np.random.uniform(-6, -2)            ## 균등(균일) 분포로 무작위 추출함
    # ================================================

    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list

# 그래프 그리기========================================================
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True): ## 정확도가 높은순으로 정렬
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)

    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1

    if i >= graph_draw_num:
        break

plt.show()
# Out:
# val acc:0.26 | lr:0.0015720139871422739, weight decay:1.330876045814616e-08
# val acc:0.07 | lr:9.707530908528521e-05, weight decay:1.0403164234885023e-07
# val acc:0.1 | lr:0.00023423959784214004, weight decay:9.073779251655395e-07
# val acc:0.15 | lr:7.771394911534794e-06, weight decay:3.917483619913519e-07
# val acc:0.13 | lr:0.00037516175368619515, weight decay:8.618998219645516e-05
# val acc:0.11 | lr:1.0352381962757492e-06, weight decay:2.5772743709443713e-05
# val acc:0.84 | lr:0.009488533933559773, weight decay:2.3235583803595415e-07
# val acc:0.13 | lr:8.444075011521056e-05, weight decay:2.046080278461491e-05
# val acc:0.12 | lr:2.7418191295562033e-05, weight decay:5.0506656451133205e-05
# val acc:0.08 | lr:2.6261772392785536e-06, weight decay:2.3292494567383242e-05
# val acc:0.27 | lr:0.0016293537985568496, weight decay:1.0951703615702346e-07
# val acc:0.49 | lr:0.004749899826602854, weight decay:5.2541157451616455e-08
# ...

# %% [markdown]
# =========== Hyper-Parameter Optimization Result ===========
#
# Best-1(val acc:0.84) | lr:0.009488533933559773, weight decay:2.3235583803595415e-07
#
# Best-2(val acc:0.68) | lr:0.007625088919054781, weight decay:3.2744214263391546e-08
#
# Best-3(val acc:0.67) | lr:0.006893109181544942, weight decay:3.0486646439434874e-06
#
# Best-4(val acc:0.65) | lr:0.004641657096034192, weight decay:1.998791198489155e-05
#
# Best-5(val acc:0.62) | lr:0.005045206758848735, weight decay:2.4731361323613483e-05
#
# Best-6(val acc:0.6) | lr:0.005022485317609375, weight decay:1.5022599075508176e-08
#
# Best-7(val acc:0.57) | lr:0.0060918089130079294, weight decay:1.616281404962164e-05
#
# Best-8(val acc:0.49) | lr:0.004749899826602854, weight decay:5.2541157451616455e-08
#
# Best-9(val acc:0.46) | lr:0.003659871057858258, weight decay:1.9055956206375769e-07
#
# Best-10(val acc:0.44) | lr:0.003651369650224961, weight decay:3.336544496069138e-07
#
# Best-11(val acc:0.43) | lr:0.003466324654557628, weight decay:3.808779781936898e-05
#
# Best-12(val acc:0.4) | lr:0.0035170109022862185, weight decay:8.439846255172992e-07
#
# Best-13(val acc:0.4) | lr:0.002477828734813634, weight decay:2.4051827565399534e-06
#
# Best-14(val acc:0.37) | lr:0.0026373745998788194, weight decay:2.6813554735388714e-06
#
# Best-15(val acc:0.35) | lr:0.002118526550804784, weight decay:2.1705241167310016e-05
#
# Best-16(val acc:0.31) | lr:0.00195567103582198, weight decay:2.973194041115141e-07
#
# Best-17(val acc:0.27) | lr:0.0016293537985568496, weight decay:1.0951703615702346e-07
#
# Best-18(val acc:0.26) | lr:0.0015720139871422739, weight decay:1.330876045814616e-08
#
# Best-19(val acc:0.25) | lr:0.0014360346229019452, weight decay:4.989199507590351e-07
#
# Best-20(val acc:0.24) | lr:0.0014437209455821862, weight decay:2.8576698313201767e-05
#
# - 주황색이 train, 하늘색이 Validation
# ![image.png](attachment:image.png)

# %% [markdown]
# Best-1(val acc:0.84) | lr:0.009488533933559773, weight decay:2.3235583803595415e-07
# 의 값을 활용하여, lr은 0.1~0.0001, weight decay는 1*10^(-8) ~ 1*10^(-6) 이런식으로 찾아간다.
#
# 학습률과 가중치 감쇠 파라미터를 서로 독립적이라고 가정하면, 위와 같은 방식이 말이 됨....
#
# 그러나 둘이 독립적인 파라미터가 아니라면, lr과 weight decay의 조합을 1만개정도 돌려서 최적값 1개를 찾는 것도 의미가 있을듯

# %%
np.random.uniform(1, 1000, 1000)  ## 균등(균일) 분포로 무작위 추출함
# Out:
# array([994.44208519, 225.61612364, 612.27785596, 611.6361097 ,
#        716.04121521, 479.02986032, 650.76113756, 830.13822527,
#        828.86158458, 393.49839816, 546.7362047 , 438.66613584,
#        697.72143544, 656.52234018, 614.40868494, 176.41421513,
#        252.09863229, 601.9549431 , 788.23088686, 452.24630773,
#         56.85327643, 772.10359671, 283.202042  , 611.51450586,
#        781.69984447, 703.00441875, 728.51508995, 563.68019534,
#        818.83624167, 155.01758789, 625.79404403, 550.97998934,
#        994.38319768, 480.69031207, 626.83694203, 309.67122036,
#        833.80556787, 812.68853482, 514.79439296, 498.12251134,
#        739.397634  ,  78.73294428, 169.91223831, 185.87812269,
#        823.33616378, 155.99666828, 193.29854486, 929.20983076,
#        938.15488506, 429.38093312, 938.6532851 , 646.49406521,
#         44.86751247, 300.03455597, 244.04820156, 539.21944363,
#        142.53841389, 508.69122317, 344.04486404, 349.66123868,
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
